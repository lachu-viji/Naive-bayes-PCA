# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB# IT IS USED FOR CONTINOUS INPUTS LIKE DECIMAL TO PREDICT CATECORICAL WITH COMBINATION OF STANDARD SCALER 
from sklearn.metrics import accuracy_score,precision_score,recall_score# here with this performance metrices

# %%
df=pd.read_csv("large_text_dataset.csv")

# %%
df
# Out:
#                                                   text  label
# 0    victory player home run fans fans game score p...      0
# 1    astronaut telescope mission planet rocket tele...      1
# 2           victory goal player win tournament stadium      0
# 3                          goal coach coach coach fans      0
# 4         stadium pitcher home run score home run goal      0
# ..                                                 ...    ...
# 495  victory player tournament team coach tournamen...      0
# 496                  match win player win pitcher goal      0
# 497  game game match coach victory player goal home...      0
# 498  fans pitcher ball match match goal pitcher goa...      0
# 499              spacecraft mission galaxy galaxy mars      1
#
# [500 rows x 2 columns]

# %%
df.head()
# Out:
#                                                 text  label
# 0  victory player home run fans fans game score p...      0
# 1  astronaut telescope mission planet rocket tele...      1
# 2         victory goal player win tournament stadium      0
# 3                        goal coach coach coach fans      0
# 4       stadium pitcher home run score home run goal      0

# %%
df.tail()
# Out:
#                                                   text  label
# 495  victory player tournament team coach tournamen...      0
# 496                  match win player win pitcher goal      0
# 497  game game match coach victory player goal home...      0
# 498  fans pitcher ball match match goal pitcher goa...      0
# 499              spacecraft mission galaxy galaxy mars      1

# %%
df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
sports_words = ["game", "team", "player", "match", "score", "goal", "win", "stadium",
                "coach", "ball", "tournament", "pitcher", "home", "run", "fans", "victory"]

space_words = ["nasa", "rocket", "planet", "mission", "astronaut", "galaxy", "orbit",
               "satellite", "telescope", "spacecraft", "mars", "moon", "solar", "launch", "asteroid"]

# %%
df["word_count"] = df["text"].apply(lambda x: len(str(x).split()))
df["avg_word_len"] = df["text"].apply(lambda x: sum(len(w) for w in str(x).split()) / len(str(x).split()))
df["sports_count"] = df["text"].apply(lambda x: sum(w in sports_words for w in str(x).split()))
df["space_count"] = df["text"].apply(lambda x: sum(w in space_words for w in str(x).split()))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
scaler=StandardScaler()
X_train_scale=scaler.fit_transform(X_train)# it perform aggeressive
X_test_scale=scaler.transform(X_test)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
Y_pred=model.predict(X_test_scale)

# %%
print(accuracy_score(Y_test,Y_pred))
print(precision_score(Y_test,Y_pred))
print(recall_score(Y_test,Y_pred))
# Out:
# 1.0
# 1.0
# 1.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer # it is used for text dataset 

from sklearn.naive_bayes import MultinomialNB# it is used spam detection only or text data with combination count vectorizer
from sklearn.metrics import accuracy_score,precision_score,recall_score# here with this performance metrices

# %%
df=pd.read_csv("KNNAlgorithmDataset.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df=df.drop(columns=["Unnamed: 32","id"])

# %%
Y=pd.get_dummies(Y)["M"]#encoding is done for output(target value) since it is only categorical values.

# %%
vectorizer=CountVectorizer(binary=True)

# %%
X=vectorizer=df.drop(columns=['diagnosis'])
Y=df['diagnosis']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)#it wil split dataset into train test as 80 20

# %%
scaler=StandardScaler()
X_train_scale=scaler.fit_transform(X_train)# it perform aggeressive
X_test_scale=scaler.transform(X_test)

# %%
model=MultinomialNB(alpha=1.0,fit_prior=True) # Alpha is used to increase fertures count and numerical stability promote fit prior  is used for 
model.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
Y_pred=model.predict(X_test)

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.9385964912280702

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Binarizer,LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.naive_bayes import BernoulliNB# 
from sklearn.metrics import accuracy_score,precision_score,recall_score,classification_report# here with this performance metrices

# %%
df=pd.read_csv("weight-height.csv")

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight'], dtype='object')

# %%
label=LabelEncoder()
df["Gender"]=label.fit_transform(df["Gender"])

# %%
X=df.drop(columns=['Gender'])
Y=df['Gender']

# %%
binarizer = Binarizer(threshold=0.5)
X_binarized_1 = binarizer.fit_transform(X)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model=BernoulliNB()
model.fit(X_train,Y_train)
# Out:
# BernoulliNB()

# %%
Y_pred=model.predict(X_test)

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.494

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66       988
#            1       0.00      0.00      0.00      1012
#
#     accuracy                           0.49      2000
#    macro avg       0.25      0.50      0.33      2000
# weighted avg       0.24      0.49      0.33      2000
# C:\Users\Vijayalakshmi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Vijayalakshmi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Vijayalakshmi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
